# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline

import torch
import numpy as np
from torch import optim
import torchvision.utils
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,random_split

import config
from utils import imshow
from models import SiameseNetwork
from training import trainSiamese,inferenceSiamese
from datasets import SiameseNetworkDataset
from loss_functions import ContrastiveLoss

# generate_csv(config.training_dir)

import os
if not os.path.exists('state_dict'):
    os.makedirs('state_dict')

# %% [markdown]
# ## Using Image Folder Dataset

# %%
siamese_dataset = SiameseNetworkDataset(training_dir=config.training_dir,
                                        training_csv=config.training_csv,
                                        transform=transforms.Compose([transforms.Resize((config.img_height,config。img_width)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=1,
                        batch_size=8)

dataiter = iter(vis_dataloader)

example_batch = next(dataiter)

concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[1.]
#  [0.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [1.]]

# %% [markdown]
# ## Training Time!

# %%
# Split the dataset into train, validation and test sets
num_train = round(0.8*siamese_dataset.__len__())
num_validate = round(0.1*siamese_dataset.__len__())
num_test = siamese_dataset.__len__()-num_train-num_validate
siamese_train, siamese_valid, siamese_test = random_split(siamese_dataset, [num_train,num_validate,num_test])
train_dataloader = DataLoader(siamese_train,
                        shuffle=True,
                        num_workers=8,
                        batch_size=config.train_batch_size)
valid_dataloader = DataLoader(siamese_valid,
                        shuffle=True,
                        num_workers=8,
                        batch_size=1)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = config.learning_rate )

# %%
net, train_loss_history, valid_loss_history,dict_name = trainSiamese(net,criterion,optimizer,train_dataloader,
             valid_dataloader,config.train_number_epochs,do_show=True)
# Out:
# Epoch  0  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 26.67it/s]
# Epoch  0  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 225.15it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:2.53	 min:0.08	 mean:0.58	 median 0.53
# -1 features max:4.37	 min:0.48	 mean:2.01	 median 1.88
# Epoch-0	 Train loss: 0.2167	 Valid loss: 0.3624	 Valid error: 0.0855
# Epoch  1  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.22it/s]
# Epoch  1  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 236.07it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:1.38	 min:0.07	 mean:0.48	 median 0.42
# -1 features max:5.63	 min:0.62	 mean:2.58	 median 2.45
# Epoch-1	 Train loss: 0.0251	 Valid loss: 0.2203	 Valid error: 0.0370
# new model saved
# Epoch  2  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.89it/s]
# Epoch  2  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 232.52it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:1.16	 min:0.05	 mean:0.40	 median 0.35
# -1 features max:6.79	 min:0.79	 mean:2.84	 median 2.58
# Epoch-2	 Train loss: 0.1162	 Valid loss: 0.1473	 Valid error: 0.0085
# new model saved
# Epoch  3  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.27it/s]
# Epoch  3  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 226.87it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:1.22	 min:0.06	 mean:0.36	 median 0.31
# -1 features max:6.71	 min:0.66	 mean:2.89	 median 2.65
# Epoch-3	 Train loss: 0.0779	 Valid loss: 0.1250	 Valid error: 0.0142
# new model saved
# Epoch  4  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.33it/s]
# Epoch  4  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 215.71it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.96	 min:0.06	 mean:0.35	 median 0.32
# -1 features max:7.26	 min:1.16	 mean:3.24	 median 2.93
# Epoch-4	 Train loss: 0.0187	 Valid loss: 0.0925	 Valid error: 0.0000
# new model saved
# Epoch  5  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.10it/s]
# Epoch  5  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 233.89it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.86	 min:0.04	 mean:0.31	 median 0.27
# -1 features max:6.73	 min:1.19	 mean:3.19	 median 3.05
# Epoch-5	 Train loss: 0.0760	 Valid loss: 0.0786	 Valid error: 0.0000
# new model saved
# Epoch  6  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.22it/s]
# Epoch  6  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 226.99it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:1.12	 min:0.04	 mean:0.31	 median 0.29
# -1 features max:7.52	 min:1.20	 mean:3.26	 median 3.01
# Epoch-6	 Train loss: 0.0365	 Valid loss: 0.0849	 Valid error: 0.0000
# Epoch  7  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.38it/s]
# Epoch  7  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 231.57it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.95	 min:0.04	 mean:0.30	 median 0.25
# -1 features max:7.48	 min:1.08	 mean:3.34	 median 3.11
# Epoch-7	 Train loss: 0.0259	 Valid loss: 0.0790	 Valid error: 0.0000
# Epoch  8  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.12it/s]
# Epoch  8  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 230.86it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.90	 min:0.04	 mean:0.29	 median 0.25
# -1 features max:7.56	 min:1.22	 mean:3.36	 median 3.14
# Epoch-8	 Train loss: 0.0306	 Valid loss: 0.0683	 Valid error: 0.0000
# new model saved
# Epoch  9  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.67it/s]
# Epoch  9  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 224.48it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.81	 min:0.02	 mean:0.28	 median 0.24
# -1 features max:7.74	 min:1.26	 mean:3.41	 median 3.23
# Epoch-9	 Train loss: 0.0035	 Valid loss: 0.0664	 Valid error: 0.0000
# new model saved
# Epoch  10  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.65it/s]
# Epoch  10  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 217.48it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.76	 min:0.03	 mean:0.27	 median 0.25
# -1 features max:7.39	 min:1.23	 mean:3.42	 median 3.29
# Epoch-10	 Train loss: 0.0027	 Valid loss: 0.0606	 Valid error: 0.0000
# new model saved
# Epoch  11  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.44it/s]
# Epoch  11  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 240.45it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.80	 min:0.03	 mean:0.25	 median 0.22
# -1 features max:7.44	 min:1.15	 mean:3.40	 median 3.15
# Epoch-11	 Train loss: 0.0061	 Valid loss: 0.0566	 Valid error: 0.0000
# new model saved
# Epoch  12  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.42it/s]
# Epoch  12  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 211.35it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.87	 min:0.04	 mean:0.27	 median 0.24
# -1 features max:7.18	 min:1.07	 mean:3.35	 median 3.18
# Epoch-12	 Train loss: 0.0090	 Valid loss: 0.0604	 Valid error: 0.0000
# Epoch  13  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.33it/s]
# Epoch  13  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 232.52it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.84	 min:0.03	 mean:0.27	 median 0.23
# -1 features max:7.35	 min:0.91	 mean:3.50	 median 3.31
# Epoch-13	 Train loss: 0.0133	 Valid loss: 0.0615	 Valid error: 0.0000
# Epoch  14  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.20it/s]
# Epoch  14  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 232.56it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.75	 min:0.03	 mean:0.26	 median 0.24
# -1 features max:7.39	 min:0.90	 mean:3.44	 median 3.29
# Epoch-14	 Train loss: 0.0173	 Valid loss: 0.0568	 Valid error: 0.0000
# Epoch  15  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.29it/s]
# Epoch  15  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 237.88it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.80	 min:0.03	 mean:0.25	 median 0.20
# -1 features max:7.48	 min:0.76	 mean:3.44	 median 3.24
# Epoch-15	 Train loss: 0.0099	 Valid loss: 0.0602	 Valid error: 0.0028
# Epoch  16  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.42it/s]
# Epoch  16  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 219.82it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.77	 min:0.02	 mean:0.25	 median 0.21
# -1 features max:7.32	 min:0.95	 mean:3.43	 median 3.30
# Epoch-16	 Train loss: 0.0090	 Valid loss: 0.0549	 Valid error: 0.0000
# new model saved
# Epoch  17  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.35it/s]
# Epoch  17  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 231.47it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.76	 min:0.04	 mean:0.25	 median 0.21
# -1 features max:7.47	 min:0.99	 mean:3.48	 median 3.32
# Epoch-17	 Train loss: 0.0126	 Valid loss: 0.0529	 Valid error: 0.0000
# new model saved
# Epoch  18  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.21it/s]
# Epoch  18  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 224.29it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.81	 min:0.03	 mean:0.24	 median 0.21
# -1 features max:7.49	 min:1.03	 mean:3.49	 median 3.24
# Epoch-18	 Train loss: 0.0076	 Valid loss: 0.0497	 Valid error: 0.0000
# new model saved
# Epoch  19  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.40it/s]
# Epoch  19  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 243.20it/s]
# +1/-1 ratrio:0.52/0.48
# +1 features max:0.78	 min:0.03	 mean:0.23	 median 0.18
# -1 features max:7.00	 min:1.05	 mean:3.29	 median 3.11
# Epoch-19	 Train loss: 0.0109	 Valid loss: 0.0475	 Valid error: 0.0000
# new model saved

# %% [markdown]
# ## Testing

# %%
net = SiameseNetwork().cuda()
net.load_state_dict(torch.load(os.path.join("state_dict",dict_name)))
net.eval()

test_dataloader = DataLoader(siamese_test,num_workers=8,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)

test_loss, test_er = inferenceSiamese(net,criterion,test_dataloader)
print("Test loss: %.4f\t Test error: %.4f"
      %(test_loss, test_er))


for i in range(3):
    label = 0
    while label == 0:
        x0,x1,label = next(dataiter)
        label = label.detach().cpu().numpy()[0][0]

    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}\nLabel: {}'.format(euclidean_distance.item(),'Different'))

for i in range(3):
    label = 1
    while label == 1:
        x0,x1,label = next(dataiter)
        label = label.detach().cpu().numpy()[0][0]

    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}\nLabel: {}'.format(euclidean_distance.item(),'Same'))
# Out:
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 245.10it/s]
# +1/-1 ratrio:0.50/0.50
# +1 features max:0.52	 min:0.03	 mean:0.13	 median 0.12
# -1 features max:6.95	 min:0.29	 mean:3.40	 median 3.26
# Test loss: 0.0346	 Test error: 0.0028
