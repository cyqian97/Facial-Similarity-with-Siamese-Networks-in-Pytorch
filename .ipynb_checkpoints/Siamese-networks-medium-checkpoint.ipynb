# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset,random_split
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

from dataset import SiameseNetworkDataset,generate_csv
from utils import imshow, show_plot
import config
# generate_csv(config.training_dir)

# %% [markdown]
# ## Using Image Folder Dataset

# %%
siamese_dataset = SiameseNetworkDataset(training_dir=config.training_dir,
                                        training_csv=config.training_csv,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=1,
                        batch_size=8)

dataiter = iter(vis_dataloader)

example_batch = next(dataiter)

concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]]

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1, 4, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(4),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(4, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


        )

        self.fc1 = nn.Sequential(
            nn.Linear(8*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
# Split the dataset into train, validation and test sets
num_train = round(0.8*siamese_dataset.__len__())
num_validate = round(0.1*siamese_dataset.__len__())
num_test = siamese_dataset.__len__()-num_train-num_validate
siamese_train, siamese_valid, siamese_test = random_split(siamese_dataset, [num_train,num_validate,num_test])
train_dataloader = DataLoader(siamese_train,
                        shuffle=True,
                        num_workers=8,
                        batch_size=config.train_batch_size)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# Epoch number 0
#  Current loss 1.6003402238071431
#
# Epoch number 0
#  Current loss 1.9338890974329843
#
# Epoch number 0
#  Current loss 1.44003625632904
#
# Epoch number 0
#  Current loss 0.9601169642992318
#
# Epoch number 0
#  Current loss 0.8569673408346716
#
# Epoch number 0
#  Current loss 0.7146479290095158
#
# Epoch number 0
#  Current loss 0.8040064984932542
#
# Epoch number 0
#  Current loss 0.31323724133627756
#
# Epoch number 1
#  Current loss 0.529393404070288
#
# Epoch number 1
#  Current loss 0.22567125530913473
#
# Epoch number 1
#  Current loss 0.32113866513827816
#
# Epoch number 1
#  Current loss 0.2985426421135344
#
# Epoch number 1
#  Current loss 0.22725029466673732
#
# Epoch number 1
#  Current loss 0.13270168511662633
#
# Epoch number 1
#  Current loss 0.15135153699666262
#
# Epoch number 1
#  Current loss 0.3777002045618636
#
# Epoch number 2
#  Current loss 0.1322759597969707
#
# Epoch number 2
#  Current loss 0.10806812876835466
#
# Epoch number 2
#  Current loss 0.10836323956900742
#
# Epoch number 2
#  Current loss 0.09619023707987254
#
# Epoch number 2
#  Current loss 0.11394714317284525
#
# Epoch number 2
#  Current loss 0.14448072090744973
#
# Epoch number 2
#  Current loss 0.07341554822633044
#
# Epoch number 2
#  Current loss 0.20060724951326847
#
# Epoch number 3
#  Current loss 0.09867490117903799
#
# Epoch number 3
#  Current loss 0.05775646636466263
#
# Epoch number 3
#  Current loss 0.05671762554848101
#
# Epoch number 3
#  Current loss 0.05418503808323294
#
# Epoch number 3
#  Current loss 0.05535854737099726
#
# Epoch number 3
#  Current loss 0.06773759205825627
#
# Epoch number 3
#  Current loss 0.03729427813086659
#
# Epoch number 3
#  Current loss 0.06276936722653252
#
# Epoch number 4
#  Current loss 0.026102580514270814
#
# Epoch number 4
#  Current loss 0.038362959667574616
#
# Epoch number 4
#  Current loss 0.04247458599274978
#
# Epoch number 4
#  Current loss 0.08463037917535986
#
# Epoch number 4
#  Current loss 0.04095705214422196
#
# Epoch number 4
#  Current loss 0.016668106658471515
#
# Epoch number 4
#  Current loss 0.03253958898130804
#
# Epoch number 4
#  Current loss 0.10452257495905672
#
# Epoch number 5
#  Current loss 0.07631541681475938
#
# Epoch number 5
#  Current loss 0.038236342323943975
#
# Epoch number 5
#  Current loss 0.029684078082209454
#
# Epoch number 5
#  Current loss 0.021134859847370537
#
# Epoch number 5
#  Current loss 0.04769013141049072
#
# Epoch number 5
#  Current loss 0.03515669140033424
#
# Epoch number 5
#  Current loss 0.022212299452030494
#
# Epoch number 5
#  Current loss 0.04850496138845171
#
# Epoch number 6
#  Current loss 0.0510357219260186
#
# Epoch number 6
#  Current loss 0.03617003308027052
#
# Epoch number 6
#  Current loss 0.019354215619387105
#
# Epoch number 6
#  Current loss 0.03957172239897773
#
# Epoch number 6
#  Current loss 0.04268938086461276
#
# Epoch number 6
#  Current loss 0.02459353073500097
#
# Epoch number 6
#  Current loss 0.0175510200439021
#
# Epoch number 6
#  Current loss 0.033773146835821014
#
# Epoch number 7
#  Current loss 0.048145039992232345
#
# Epoch number 7
#  Current loss 0.011916064278921112
#
# Epoch number 7
#  Current loss 0.02177576010581106
#
# Epoch number 7
#  Current loss 0.01548587594588753
#
# Epoch number 7
#  Current loss 0.02289189546718262
#
# Epoch number 7
#  Current loss 0.02689778137137182
#
# Epoch number 7
#  Current loss 0.014911613211734221
#
# Epoch number 7
#  Current loss 0.009222797783357757
#
# Epoch number 8
#  Current loss 0.0120112310978584
#
# Epoch number 8
#  Current loss 0.015655045054154472
#
# Epoch number 8
#  Current loss 0.015640226553659885
#
# Epoch number 8
#  Current loss 0.008941807795781643
#
# Epoch number 8
#  Current loss 0.024013737716359174
#
# Epoch number 8
#  Current loss 0.016895023186225443
#
# Epoch number 8
#  Current loss 0.013809338200371713
#
# Epoch number 8
#  Current loss 0.019135974879775728
#
# Epoch number 9
#  Current loss 0.018449576938292012
#
# Epoch number 9
#  Current loss 0.016991068469360472
#
# Epoch number 9
#  Current loss 0.014359198944885066
#
# Epoch number 9
#  Current loss 0.019084044202463703
#
# Epoch number 9
#  Current loss 0.026943129306891935
#
# Epoch number 9
#  Current loss 0.016107699746498838
#
# Epoch number 9
#  Current loss 0.012711793845846843
#
# Epoch number 9
#  Current loss 0.007380259073605494
#
# Epoch number 10
#  Current loss 0.01856489006895572
#
# Epoch number 10
#  Current loss 0.03258804209181108
#
# Epoch number 10
#  Current loss 0.010292846814263613
#
# Epoch number 10
#  Current loss 0.01113023979123682
#
# Epoch number 10
#  Current loss 0.011420551987248473
#
# Epoch number 10
#  Current loss 0.016894085667445324
#
# Epoch number 10
#  Current loss 0.01805882220505737
#
# Epoch number 10
#  Current loss 0.014776247753096477
#
# Epoch number 11
#  Current loss 0.009397857409203425
#
# Epoch number 11
#  Current loss 0.019993283652001995
#
# Epoch number 11
#  Current loss 0.010910289239836857
#
# Epoch number 11
#  Current loss 0.019134353060508147
#
# Epoch number 11
#  Current loss 0.011865287588443608
#
# Epoch number 11
#  Current loss 0.010384303756291048
#
# Epoch number 11
#  Current loss 0.008700531095382758
#
# Epoch number 11
#  Current loss 0.014045149487044129
#
# Epoch number 12
#  Current loss 0.010848193516721949
#
# Epoch number 12
#  Current loss 0.011024374671978877
#
# Epoch number 12
#  Current loss 0.01087777175125666
#
# Epoch number 12
#  Current loss 0.009252601792104543
#
# Epoch number 12
#  Current loss 0.010636988820624539
#
# Epoch number 12
#  Current loss 0.005263052991358564
#
# Epoch number 12
#  Current loss 0.00978702228749171
#
# Epoch number 12
#  Current loss 0.009076136430459363
#
# Epoch number 13
#  Current loss 0.009316256401871215
#
# Epoch number 13
#  Current loss 0.010811318477499299
#
# Epoch number 13
#  Current loss 0.011069237714400515
#
# Epoch number 13
#  Current loss 0.007913836593797897
#
# Epoch number 13
#  Current loss 0.01007392463297947
#
# Epoch number 13
#  Current loss 0.006075206736659311
#
# Epoch number 13
#  Current loss 0.007844258151453688
#
# Epoch number 13
#  Current loss 0.00599514227360487
#
# Epoch number 14
#  Current loss 0.006634496593324002
#
# Epoch number 14
#  Current loss 0.009181076218374074
#
# Epoch number 14
#  Current loss 0.006819581729359925
#
# Epoch number 14
#  Current loss 0.00910656934720464
#
# Epoch number 14
#  Current loss 0.005155950942207711
#
# Epoch number 14
#  Current loss 0.009667823799100007
#
# Epoch number 14
#  Current loss 0.012623974966118112
#
# Epoch number 14
#  Current loss 0.006174659522782479
#
# Epoch number 15
#  Current loss 0.005309394531650469
#
# Epoch number 15
#  Current loss 0.005676694588328247
#
# Epoch number 15
#  Current loss 0.009683715568098706
#
# Epoch number 15
#  Current loss 0.00832211860397365
#
# Epoch number 15
#  Current loss 0.003227203043206828
#
# Epoch number 15
#  Current loss 0.004939461828325876
#
# Epoch number 15
#  Current loss 0.003798726998502389
#
# Epoch number 15
#  Current loss 0.013854820979759097
#
# Epoch number 16
#  Current loss 0.005836294568143785
#
# Epoch number 16
#  Current loss 0.009969932807143778
#
# Epoch number 16
#  Current loss 0.01084507437699358
#
# Epoch number 16
#  Current loss 0.0078053398454358104
#
# Epoch number 16
#  Current loss 0.010774869177112123
#
# Epoch number 16
#  Current loss 0.005427948723081499
#
# Epoch number 16
#  Current loss 0.004872473783325404
#
# Epoch number 16
#  Current loss 0.0020014974953872816
#
# Epoch number 17
#  Current loss 0.008901791708194651
#
# Epoch number 17
#  Current loss 0.00809850748773897
#
# Epoch number 17
#  Current loss 0.007222245261800708
#
# Epoch number 17
#  Current loss 0.010445652090129444
#
# Epoch number 17
#  Current loss 0.009703280837857165
#
# Epoch number 17
#  Current loss 0.01501512967515737
#
# Epoch number 17
#  Current loss 0.006684856576612219
#
# Epoch number 17
#  Current loss 0.017936482692935636
#
# Epoch number 18
#  Current loss 0.005792626496986486
#
# Epoch number 18
#  Current loss 0.00541117047428088
#
# Epoch number 18
#  Current loss 0.005241086558089592
#
# Epoch number 18
#  Current loss 0.006028832944502938
#
# Epoch number 18
#  Current loss 0.011510389726026915
#
# Epoch number 18
#  Current loss 0.009961284672317562
#
# Epoch number 18
#  Current loss 0.009891926770797
#
# Epoch number 18
#  Current loss 0.005473149873848472
#
# Epoch number 19
#  Current loss 0.005489642018801533
#
# Epoch number 19
#  Current loss 0.00950694020575611
#
# Epoch number 19
#  Current loss 0.010279263748088852
#
# Epoch number 19
#  Current loss 0.0048861476505408065
#
# Epoch number 19
#  Current loss 0.0075612885902955895
#
# Epoch number 19
#  Current loss 0.012303808311116882
#
# Epoch number 19
#  Current loss 0.010573863686295227
#
# Epoch number 19
#  Current loss 0.011021962389349937

# %% [markdown]
# ## Some simple testing
# The last 3 subjects were held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.

# %%
folder_dataset_test = dset.ImageFolder(root=config.testing_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_21871/2922340456.py in <module>
# ----> 1 folder_dataset_test = dset.ImageFolder(root=config.testing_dir)
#       2 siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
#       3                                         transform=transforms.Compose([transforms.Resize((100,100)),
#       4                                                                       transforms.ToTensor()
#       5                                                                       ])
#
# AttributeError: module 'config' has no attribute 'testing_dir'
