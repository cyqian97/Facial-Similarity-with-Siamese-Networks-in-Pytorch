# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline

import torch
import numpy as np
from torch import optim
import torchvision.utils
from torch.autograd import Variable
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,random_split

import config
from utils import imshow
from models import SiameseNetwork
from training import trainSiamese
from datasets import SiameseNetworkDataset
from loss_functions import ContrastiveLoss

# generate_csv(config.training_dir)

import os
if not os.path.exists('state_dict'):
    os.makedirs('state_dict')

# %% [markdown]
# ## Using Image Folder Dataset

# %%
siamese_dataset = SiameseNetworkDataset(training_dir=config.training_dir,
                                        training_csv=config.training_csv,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=1,
                        batch_size=8)

dataiter = iter(vis_dataloader)

example_batch = next(dataiter)

concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[1.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]
#  [1.]
#  [1.]
#  [1.]]

# %% [markdown]
# ## Training Time!

# %%
# Split the dataset into train, validation and test sets
num_train = round(0.8*siamese_dataset.__len__())
num_validate = round(0.1*siamese_dataset.__len__())
num_test = siamese_dataset.__len__()-num_train-num_validate
siamese_train, siamese_valid, siamese_test = random_split(siamese_dataset, [num_train,num_validate,num_test])
train_dataloader = DataLoader(siamese_train,
                        shuffle=True,
                        num_workers=8,
                        batch_size=config.train_batch_size)
valid_dataloader = DataLoader(siamese_valid,
                        shuffle=True,
                        num_workers=8,
                        batch_size=1)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.0005 )

# %%
net, train_loss_history, valid_loss_history,dict_name = trainSiamese(net,criterion,optimizer,train_dataloader,
             valid_dataloader,config.train_number_epochs,do_show=True)
# Out:
# Epoch  0  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 26.54it/s]
# Epoch  0  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 229.96it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.67	 min:0.11	 mean:0.64	 median 0.59
# -1 features max:3.04	 min:0.33	 mean:1.43	 median 1.41
# Epoch-0	 Train loss: 0.2524	 Valid loss: 0.5109	 Valid error: 0.1254
# Epoch  1  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.99it/s]
# Epoch  1  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 233.16it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.31	 min:0.10	 mean:0.52	 median 0.50
# -1 features max:4.08	 min:0.19	 mean:2.10	 median 2.09
# Epoch-1	 Train loss: 0.0883	 Valid loss: 0.2667	 Valid error: 0.0427
# new model saved
# Epoch  2  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.52it/s]
# Epoch  2  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 230.96it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.33	 min:0.09	 mean:0.48	 median 0.43
# -1 features max:4.10	 min:0.55	 mean:2.14	 median 2.22
# Epoch-2	 Train loss: 0.1213	 Valid loss: 0.2391	 Valid error: 0.0342
# new model saved
# Epoch  3  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.41it/s]
# Epoch  3  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 226.42it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.47	 min:0.09	 mean:0.47	 median 0.43
# -1 features max:4.37	 min:0.46	 mean:2.31	 median 2.29
# Epoch-3	 Train loss: 0.0325	 Valid loss: 0.2077	 Valid error: 0.0285
# new model saved
# Epoch  4  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.57it/s]
# Epoch  4  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 235.04it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.18	 min:0.07	 mean:0.44	 median 0.40
# -1 features max:4.60	 min:0.70	 mean:2.49	 median 2.51
# Epoch-4	 Train loss: 0.0277	 Valid loss: 0.1652	 Valid error: 0.0171
# new model saved
# Epoch  5  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.34it/s]
# Epoch  5  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 228.43it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.67	 min:0.07	 mean:0.41	 median 0.37
# -1 features max:4.54	 min:0.80	 mean:2.49	 median 2.51
# Epoch-5	 Train loss: 0.0643	 Valid loss: 0.1595	 Valid error: 0.0171
# Epoch  6  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.74it/s]
# Epoch  6  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 244.38it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.40	 min:0.10	 mean:0.40	 median 0.36
# -1 features max:4.78	 min:0.87	 mean:2.56	 median 2.53
# Epoch-6	 Train loss: 0.0194	 Valid loss: 0.1369	 Valid error: 0.0142
# new model saved
# Epoch  7  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.58it/s]
# Epoch  7  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 236.17it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.16	 min:0.04	 mean:0.40	 median 0.35
# -1 features max:5.07	 min:0.85	 mean:2.62	 median 2.65
# Epoch-7	 Train loss: 0.0833	 Valid loss: 0.1357	 Valid error: 0.0085
# new model saved
# Epoch  8  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.53it/s]
# Epoch  8  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 234.29it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.42	 min:0.03	 mean:0.38	 median 0.35
# -1 features max:5.18	 min:0.91	 mean:2.66	 median 2.70
# Epoch-8	 Train loss: 0.0226	 Valid loss: 0.1264	 Valid error: 0.0085
# Epoch  9  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 32.09it/s]
# Epoch  9  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 247.59it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.37	 min:0.07	 mean:0.37	 median 0.34
# -1 features max:5.36	 min:0.85	 mean:2.69	 median 2.74
# Epoch-9	 Train loss: 0.1215	 Valid loss: 0.1244	 Valid error: 0.0114
# Epoch  10  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.66it/s]
# Epoch  10  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 227.71it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.32	 min:0.06	 mean:0.38	 median 0.35
# -1 features max:5.18	 min:0.83	 mean:2.74	 median 2.80
# Epoch-10	 Train loss: 0.0280	 Valid loss: 0.1245	 Valid error: 0.0085
# Epoch  11  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.57it/s]
# Epoch  11  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 250.04it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.42	 min:0.04	 mean:0.34	 median 0.29
# -1 features max:4.88	 min:0.87	 mean:2.60	 median 2.67
# Epoch-11	 Train loss: 0.0210	 Valid loss: 0.1154	 Valid error: 0.0085
# Epoch  12  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.15it/s]
# Epoch  12  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 224.81it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.44	 min:0.05	 mean:0.33	 median 0.30
# -1 features max:5.18	 min:0.87	 mean:2.66	 median 2.71
# Epoch-12	 Train loss: 0.0133	 Valid loss: 0.1069	 Valid error: 0.0057
# new model saved
# Epoch  13  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.40it/s]
# Epoch  13  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 233.48it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.42	 min:0.05	 mean:0.34	 median 0.31
# -1 features max:5.03	 min:0.90	 mean:2.79	 median 2.90
# Epoch-13	 Train loss: 0.0116	 Valid loss: 0.1068	 Valid error: 0.0085
# Epoch  14  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.56it/s]
# Epoch  14  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 228.99it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.42	 min:0.05	 mean:0.35	 median 0.31
# -1 features max:5.29	 min:0.79	 mean:2.89	 median 2.96
# Epoch-14	 Train loss: 0.0320	 Valid loss: 0.1098	 Valid error: 0.0085
# Epoch  15  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.79it/s]
# Epoch  15  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 240.99it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.31	 min:0.04	 mean:0.33	 median 0.28
# -1 features max:5.11	 min:0.91	 mean:2.80	 median 2.87
# Epoch-15	 Train loss: 0.0556	 Valid loss: 0.0992	 Valid error: 0.0085
# Epoch  16  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.55it/s]
# Epoch  16  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 230.96it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.52	 min:0.02	 mean:0.33	 median 0.28
# -1 features max:4.82	 min:0.94	 mean:2.77	 median 2.81
# Epoch-16	 Train loss: 0.0061	 Valid loss: 0.1008	 Valid error: 0.0085
# Epoch  17  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.49it/s]
# Epoch  17  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 234.18it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.41	 min:0.03	 mean:0.30	 median 0.27
# -1 features max:4.66	 min:0.86	 mean:2.73	 median 2.81
# Epoch-17	 Train loss: 0.0151	 Valid loss: 0.0885	 Valid error: 0.0085
# Epoch  18  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.64it/s]
# Epoch  18  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 226.56it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.32	 min:0.05	 mean:0.31	 median 0.27
# -1 features max:4.97	 min:0.85	 mean:2.81	 median 2.89
# Epoch-18	 Train loss: 0.0074	 Valid loss: 0.0921	 Valid error: 0.0114
# Epoch  19  training
# 100%|███████████████████████████████████████████| 71/71 [00:02<00:00, 31.78it/s]
# Epoch  19  validating
# 100%|████████████████████████████████████████| 351/351 [00:01<00:00, 232.85it/s]
# +1/-1 ratrio:0.53/0.47
# +1 features max:1.36	 min:0.03	 mean:0.30	 median 0.26
# -1 features max:5.10	 min:0.77	 mean:2.84	 median 2.95
# Epoch-19	 Train loss: 0.0077	 Valid loss: 0.0909	 Valid error: 0.0114

# %% [markdown]
# ## Some simple testing
# The last 3 subjects were held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.

# %%
vis_dataloader = DataLoader(siamese_test,
                        shuffle=True,
                        num_workers=1,
                        batch_size=8)

dataiter = iter(vis_dataloader)

example_batch = next(dataiter)

concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[0.]
#  [0.]
#  [1.]
#  [0.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]]

# %%
test_dataloader = DataLoader(siamese_test,num_workers=8,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)

for i in range(3):
    label = 0
    while label == 0:
        x0,x1,label = next(dataiter)
        label = label.detach().cpu().numpy()[0][0]

    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}\nLabel: {}'.format(euclidean_distance.item(),'Different'))

    test_dataloader = DataLoader(siamese_test,num_workers=8,batch_size=1,shuffle=True)


for i in range(3):
    label = 1
    while label == 1:
        x0,x1,label = next(dataiter)
        label = label.detach().cpu().numpy()[0][0]

    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}\nLabel: {}'.format(euclidean_distance.item(),'Same'))

# %%
test_dataloader = DataLoader(siamese_test,num_workers=8,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)

for i in range(3):
    label = 0
    while label == 0:
        x0,x1,label = next(dataiter)
        label = label.detach().cpu().numpy()[0][0]

    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}\nLabel: {}'.format(euclidean_distance.item(),'Different'))

for i in range(3):
    label = 1
    while label == 1:
        x0,x1,label = next(dataiter)
        label = label.detach().cpu().numpy()[0][0]

    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}\nLabel: {}'.format(euclidean_distance.item(),'Same'))
